# %%
# importamos librería
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from datetime import datetime, timedelta

from sklearn.preprocessing import LabelEncoder,MinMaxScaler

import folium
import plotly.express as px

# %%
DATA_PATH = './data_dsmarket'

# %% [markdown]
# # **Dataset Eventos**

# %%
df_events = pd.read_csv(os.path.join(DATA_PATH,"daily_calendar_with_events.csv"))

# %%
df_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1913 entries, 0 to 1912
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1913 non-null   object
#  1   weekday      1913 non-null   object
#  2   weekday_int  1913 non-null   int64
#  3   d            1913 non-null   object
#  4   event        26 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 74.9+ KB

# %%
# Change format of date column

df_events['date'] = pd.to_datetime(df_events['date'], format='%Y-%m-%d')

# %%
FIRST_DAY = df_events['date'].min()
FIRST_DAY
# Out:
# Timestamp('2011-01-29 00:00:00')

# %%
df_events.drop(df_events[df_events['date'] < pd.to_datetime('31-01-2011', format = '%d-%m-%Y')].index, inplace=True)

# %%
# Change order of columns
order_of_columns = [
  'date',
  'd',
  'weekday',
  'weekday_int',
  'event'
]
df_events = df_events[order_of_columns]

# %%
df_events.head(14)
# Out:
#          date     d    weekday  weekday_int      event
# 2  2011-01-31   d_3     Monday            3        NaN
# 3  2011-02-01   d_4    Tuesday            4        NaN
# 4  2011-02-02   d_5  Wednesday            5        NaN
# 5  2011-02-03   d_6   Thursday            6        NaN
# 6  2011-02-04   d_7     Friday            7        NaN
# 7  2011-02-05   d_8   Saturday            1        NaN
# 8  2011-02-06   d_9     Sunday            2  SuperBowl
# 9  2011-02-07  d_10     Monday            3        NaN
# 10 2011-02-08  d_11    Tuesday            4        NaN
# 11 2011-02-09  d_12  Wednesday            5        NaN
# 12 2011-02-10  d_13   Thursday            6        NaN
# 13 2011-02-11  d_14     Friday            7        NaN
# 14 2011-02-12  d_15   Saturday            1        NaN
# 15 2011-02-13  d_16     Sunday            2        NaN

# %%
df_events.event.unique()
# Out:
# array([nan, 'SuperBowl', 'Ramadan starts', 'Thanksgiving', 'NewYear',
#        'Easter'], dtype=object)

# %%
df_events.isnull().sum()
# Out:
# date              0
# d                 0
# weekday           0
# weekday_int       0
# event          1885
# dtype: int64

# %%
df_events.fillna("None", inplace=True)

# %%
# One Hot Encoding of events column
df_events = pd.get_dummies(data=df_events, columns=['event'], drop_first=True, dtype='bool')

# %%
df_events
# Out:
#            date       d    weekday  weekday_int  event_NewYear  event_None  \
# 2    2011-01-31     d_3     Monday            3          False        True
# 3    2011-02-01     d_4    Tuesday            4          False        True
# 4    2011-02-02     d_5  Wednesday            5          False        True
# 5    2011-02-03     d_6   Thursday            6          False        True
# 6    2011-02-04     d_7     Friday            7          False        True
# ...         ...     ...        ...          ...            ...         ...
# 1908 2016-04-20  d_1909  Wednesday            5          False        True
# 1909 2016-04-21  d_1910   Thursday            6          False        True
# 1910 2016-04-22  d_1911     Friday            7          False        True
# 1911 2016-04-23  d_1912   Saturday            1          False        True
# 1912 2016-04-24  d_1913     Sunday            2          False        True
#
#       event_Ramadan starts  event_SuperBowl  event_Thanksgiving
# 2                    False            False               False
# 3                    False            False               False
# 4                    False            False               False
# 5                    False            False               False
# 6                    False            False               False
# ...                    ...              ...                 ...
# 1908                 False            False               False
# 1909                 False            False               False
# 1910                 False            False               False
# 1911                 False            False               False
# 1912                 False            False               False
#
# [1911 rows x 9 columns]

# %%
ramadan_start_dates = []
for _, row in df_events.iterrows():
    if row['event_Ramadan starts']:
        ramadan_start_dates.append(row['date'])

ramadan_dates = []
for date in ramadan_start_dates:
    new_date = date
    for i in range(30):
        ramadan_dates.append(new_date)
        new_date += timedelta(days=1)

for date in ramadan_dates:
    df_events.loc[df_events['date'] == date, 'event_None'] = False
    df_events.loc[df_events['date'] == date, 'event_Ramadan'] = True

# %%
df_events.isnull().sum()
# Out:
# date                       0
# d                          0
# weekday                    0
# weekday_int                0
# event_NewYear              0
# event_None                 0
# event_Ramadan starts       0
# event_SuperBowl            0
# event_Thanksgiving         0
# event_Ramadan           1761
# dtype: int64

# %%
df_events.fillna(value=False, inplace=True)

# %%
df_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 2 to 1912
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  1911 non-null   datetime64[ns]
#  1   d                     1911 non-null   object
#  2   weekday               1911 non-null   object
#  3   weekday_int           1911 non-null   int64
#  4   event_NewYear         1911 non-null   bool
#  5   event_None            1911 non-null   bool
#  6   event_Ramadan starts  1911 non-null   bool
#  7   event_SuperBowl       1911 non-null   bool
#  8   event_Thanksgiving    1911 non-null   bool
#  9   event_Ramadan         1911 non-null   bool
# dtypes: bool(6), datetime64[ns](1), int64(1), object(2)
# memory usage: 71.0+ KB

# %%
df_events.drop(columns='event_Ramadan starts', inplace=True)

# %%
event_columns = df_events.select_dtypes(include='bool').columns
df_events = df_events.groupby(pd.Grouper(key='date', freq='W'))[event_columns].any()

# %%
df_events
# Out:
#             event_NewYear  event_None  event_SuperBowl  event_Thanksgiving  \
# date
# 2011-02-06          False        True             True               False
# 2011-02-13          False        True            False               False
# 2011-02-20          False        True            False               False
# 2011-02-27          False        True            False               False
# 2011-03-06          False        True            False               False
# ...                   ...         ...              ...                 ...
# 2016-03-27          False        True            False               False
# 2016-04-03          False        True            False               False
# 2016-04-10          False        True            False               False
# 2016-04-17          False        True            False               False
# 2016-04-24          False        True            False               False
#
#             event_Ramadan
# date
# 2011-02-06          False
# 2011-02-13          False
# 2011-02-20          False
# 2011-02-27          False
# 2011-03-06          False
# ...                   ...
# 2016-03-27          False
# 2016-04-03          False
# 2016-04-10          False
# 2016-04-17          False
# 2016-04-24          False
#
# [273 rows x 5 columns]

# %%
df_events.iloc[0].any()
# Out:
# True

# %%
def cambiar_valores(row):
    if row.any():
        return False
    else:
        return True

# %%
df_events['event_None'] = df_events.apply(cambiar_valores, axis=1)

# %%
df_events.reset_index(inplace=True)

# %%
#df_events.to_csv(os.path.join(DATA_PATH,"preproc_data/events_cleaned.csv"))

# %% [markdown]
# # **Dataset Precios**

# %%
df_prices = pd.read_csv(os.path.join(DATA_PATH,"item_prices.csv"))

# %%
df_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6965706 entries, 0 to 6965705
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   item        object
#  1   category    object
#  2   store_code  object
#  3   yearweek    float64
#  4   sell_price  float64
# dtypes: float64(2), object(3)
# memory usage: 265.7+ MB

# %%
df_prices.head(20)
# Out:
#                 item    category store_code  yearweek  sell_price
# 0   ACCESORIES_1_001  ACCESORIES      NYC_1  201328.0     12.7414
# 1   ACCESORIES_1_001  ACCESORIES      NYC_1  201329.0     12.7414
# 2   ACCESORIES_1_001  ACCESORIES      NYC_1  201330.0     10.9858
# 3   ACCESORIES_1_001  ACCESORIES      NYC_1  201331.0     10.9858
# 4   ACCESORIES_1_001  ACCESORIES      NYC_1  201332.0     10.9858
# 5   ACCESORIES_1_001  ACCESORIES      NYC_1  201333.0     10.9858
# 6   ACCESORIES_1_001  ACCESORIES      NYC_1  201334.0     10.9858
# 7   ACCESORIES_1_001  ACCESORIES      NYC_1  201335.0     10.9858
# 8   ACCESORIES_1_001  ACCESORIES      NYC_1  201336.0     10.9858
# 9   ACCESORIES_1_001  ACCESORIES      NYC_1  201337.0     10.9858
# 10  ACCESORIES_1_001  ACCESORIES      NYC_1  201338.0     10.9858
# 11  ACCESORIES_1_001  ACCESORIES      NYC_1  201339.0     10.9858
# 12  ACCESORIES_1_001  ACCESORIES      NYC_1  201340.0     10.9858
# 13  ACCESORIES_1_001  ACCESORIES      NYC_1  201341.0     10.9858
# 14  ACCESORIES_1_001  ACCESORIES      NYC_1  201342.0     10.9858
# 15  ACCESORIES_1_001  ACCESORIES      NYC_1  201343.0     10.9858
# 16  ACCESORIES_1_001  ACCESORIES      NYC_1  201344.0     10.9858
# 17  ACCESORIES_1_001  ACCESORIES      NYC_1  201345.0     10.9858
# 18  ACCESORIES_1_001  ACCESORIES      NYC_1  201346.0     10.9858
# 19  ACCESORIES_1_001  ACCESORIES      NYC_1  201347.0     10.9858

# %%
df_prices[df_prices['item']  == 'ACCESORIES_1_001']
# Out:
#                      item    category store_code  yearweek  sell_price
# 0        ACCESORIES_1_001  ACCESORIES      NYC_1  201328.0     12.7414
# 1        ACCESORIES_1_001  ACCESORIES      NYC_1  201329.0     12.7414
# 2        ACCESORIES_1_001  ACCESORIES      NYC_1  201330.0     10.9858
# 3        ACCESORIES_1_001  ACCESORIES      NYC_1  201331.0     10.9858
# 4        ACCESORIES_1_001  ACCESORIES      NYC_1  201332.0     10.9858
# ...                   ...         ...        ...       ...         ...
# 6257108  ACCESORIES_1_001  ACCESORIES      PHI_3       NaN     11.1454
# 6257109  ACCESORIES_1_001  ACCESORIES      PHI_3       NaN     11.1454
# 6257110  ACCESORIES_1_001  ACCESORIES      PHI_3       NaN     11.1454
# 6257111  ACCESORIES_1_001  ACCESORIES      PHI_3       NaN     11.1454
# 6257112  ACCESORIES_1_001  ACCESORIES      PHI_3       NaN     11.1454
#
# [1558 rows x 5 columns]

# %%
df_prices.isnull().sum()
# Out:
# item               0
# category           0
# store_code         0
# yearweek      243920
# sell_price         0
# dtype: int64

# %%
df_prices.yearweek.min()
# Out:
# 201105.0

# %%
df_prices.dropna(inplace=True)

# %%
# Year week to date (Stablishing Sunday for every record as it's the last day)
df_prices['yearweek'] = pd.to_datetime(
    (df_prices['yearweek'].astype(int)).astype(str) + '-0', 
    format='%Y%W-%w'
)

# %%
df_prices.rename(columns={'yearweek':'date'}, inplace=True)

# %%
df_prices.sort_values(by=['item','date', 'store_code'], inplace=True)

# %%
df_prices.reset_index(drop=True,inplace=True)

# %%
order_of_columns = [
  'item',
  'date',
  'store_code',
  'category',
  'sell_price'
]
df_prices = df_prices[order_of_columns]

# %%
len(df_prices['item'].unique())
# Out:
# 3049

# %%
df_prices.date.min()
# Out:
# Timestamp('2011-02-06 00:00:00')

# %%
df_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6721786 entries, 0 to 6721785
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   item        object
#  1   date        datetime64[ns]
#  2   store_code  object
#  3   category    object
#  4   sell_price  float64
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 256.4+ MB

# %%
#df_prices.to_csv(os.path.join(DATA_PATH,"preproc_data/prices_cleaned.csv"))

# %% [markdown]
# # **Dataset Ventas**

# %%
df_sales = pd.read_csv(os.path.join(DATA_PATH,"item_sales.csv"))

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30490 entries, 0 to 30489
# Columns: 1920 entries, id to d_1913
# dtypes: int64(1913), object(7)
# memory usage: 446.6+ MB

# %%
df_sales.head()
# Out:
#                        id              item    category    department  \
# 0  ACCESORIES_1_001_NYC_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
# 1  ACCESORIES_1_002_NYC_1  ACCESORIES_1_002  ACCESORIES  ACCESORIES_1
# 2  ACCESORIES_1_003_NYC_1  ACCESORIES_1_003  ACCESORIES  ACCESORIES_1
# 3  ACCESORIES_1_004_NYC_1  ACCESORIES_1_004  ACCESORIES  ACCESORIES_1
# 4  ACCESORIES_1_005_NYC_1  ACCESORIES_1_005  ACCESORIES  ACCESORIES_1
#
#                store store_code    region  d_1  d_2  d_3  ...  d_1904  d_1905  \
# 0  Greenwich_Village      NYC_1  New York    0    0    0  ...       1       3
# 1  Greenwich_Village      NYC_1  New York    0    0    0  ...       0       0
# 2  Greenwich_Village      NYC_1  New York    0    0    0  ...       2       1
# 3  Greenwich_Village      NYC_1  New York    0    0    0  ...       1       0
# 4  Greenwich_Village      NYC_1  New York    0    0    0  ...       2       1
#
#    d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 0       0       1       1       1       3       0       1       1
# 1       0       0       0       1       0       0       0       0
# 2       2       1       1       1       0       1       1       1
# 3       5       4       1       0       1       3       7       2
# 4       1       0       1       1       2       2       2       4
#
# [5 rows x 1920 columns]

# %%
len(df_sales.item.unique())
# Out:
# 3049

# %%
df_sales.set_index('id', inplace=True)

# %%
column_names = list(df_sales.columns)
columns_to_select = column_names[8:]

# %%
df_sales_stack = df_sales.loc[:,columns_to_select].stack()

# %%
df_sales_stack = df_sales_stack.reset_index()

# %%
df_sales_stack.rename(columns={'level_1':'day', 0:'sales_count'}, inplace=True)

# %%
df_sales_stack
# Out:
#                                id     day  sales_count
# 0          ACCESORIES_1_001_NYC_1     d_3            0
# 1          ACCESORIES_1_001_NYC_1     d_4            0
# 2          ACCESORIES_1_001_NYC_1     d_5            0
# 3          ACCESORIES_1_001_NYC_1     d_6            0
# 4          ACCESORIES_1_001_NYC_1     d_7            0
# ...                           ...     ...          ...
# 58266385  SUPERMARKET_3_827_PHI_3  d_1909            0
# 58266386  SUPERMARKET_3_827_PHI_3  d_1910            0
# 58266387  SUPERMARKET_3_827_PHI_3  d_1911            0
# 58266388  SUPERMARKET_3_827_PHI_3  d_1912            0
# 58266389  SUPERMARKET_3_827_PHI_3  d_1913            0
#
# [58266390 rows x 3 columns]

# %%
df_sales_stack['date'] = None
df_sales_stack['day'] = df_sales_stack['day'].apply(lambda x: x.split('_')[1])
df_sales_stack['date'] = FIRST_DAY +  pd.to_timedelta(df_sales_stack['day'].astype(int)-1, unit='d')

print(df_sales_stack)
# Out:
#                                id   day  sales_count       date
# 0          ACCESORIES_1_001_NYC_1     3            0 2011-01-31
# 1          ACCESORIES_1_001_NYC_1     4            0 2011-02-01
# 2          ACCESORIES_1_001_NYC_1     5            0 2011-02-02
# 3          ACCESORIES_1_001_NYC_1     6            0 2011-02-03
# 4          ACCESORIES_1_001_NYC_1     7            0 2011-02-04
# ...                           ...   ...          ...        ...
# 58266385  SUPERMARKET_3_827_PHI_3  1909            0 2016-04-20
# 58266386  SUPERMARKET_3_827_PHI_3  1910            0 2016-04-21
# 58266387  SUPERMARKET_3_827_PHI_3  1911            0 2016-04-22
# 58266388  SUPERMARKET_3_827_PHI_3  1912            0 2016-04-23
# 58266389  SUPERMARKET_3_827_PHI_3  1913            0 2016-04-24
#
# [58266390 rows x 4 columns]

# %%
df_sales_stack = df_sales_stack.set_index("date").groupby(["id"]).resample('W')['sales_count'].sum().reset_index()

# %%
df_sales_stack.date.min()
# Out:
# Timestamp('2011-02-06 00:00:00')

# %%
column_names = list(df_sales.columns)
columns_to_select = column_names[0:6]

# %%
df_sales = df_sales.loc[:,columns_to_select]

# %%
df_sales
# Out:
#                                       item     category     department  \
# id
# ACCESORIES_1_001_NYC_1    ACCESORIES_1_001   ACCESORIES   ACCESORIES_1
# ACCESORIES_1_002_NYC_1    ACCESORIES_1_002   ACCESORIES   ACCESORIES_1
# ACCESORIES_1_003_NYC_1    ACCESORIES_1_003   ACCESORIES   ACCESORIES_1
# ACCESORIES_1_004_NYC_1    ACCESORIES_1_004   ACCESORIES   ACCESORIES_1
# ACCESORIES_1_005_NYC_1    ACCESORIES_1_005   ACCESORIES   ACCESORIES_1
# ...                                    ...          ...            ...
# SUPERMARKET_3_823_PHI_3  SUPERMARKET_3_823  SUPERMARKET  SUPERMARKET_3
# SUPERMARKET_3_824_PHI_3  SUPERMARKET_3_824  SUPERMARKET  SUPERMARKET_3
# SUPERMARKET_3_825_PHI_3  SUPERMARKET_3_825  SUPERMARKET  SUPERMARKET_3
# SUPERMARKET_3_826_PHI_3  SUPERMARKET_3_826  SUPERMARKET  SUPERMARKET_3
# SUPERMARKET_3_827_PHI_3  SUPERMARKET_3_827  SUPERMARKET  SUPERMARKET_3
#
#                                      store store_code        region
# id
# ACCESORIES_1_001_NYC_1   Greenwich_Village      NYC_1      New York
# ACCESORIES_1_002_NYC_1   Greenwich_Village      NYC_1      New York
# ACCESORIES_1_003_NYC_1   Greenwich_Village      NYC_1      New York
# ACCESORIES_1_004_NYC_1   Greenwich_Village      NYC_1      New York
# ACCESORIES_1_005_NYC_1   Greenwich_Village      NYC_1      New York
# ...                                    ...        ...           ...
# SUPERMARKET_3_823_PHI_3      Queen_Village      PHI_3  Philadelphia
# SUPERMARKET_3_824_PHI_3      Queen_Village      PHI_3  Philadelphia
# SUPERMARKET_3_825_PHI_3      Queen_Village      PHI_3  Philadelphia
# SUPERMARKET_3_826_PHI_3      Queen_Village      PHI_3  Philadelphia
# SUPERMARKET_3_827_PHI_3      Queen_Village      PHI_3  Philadelphia
#
# [30490 rows x 6 columns]

# %%
df_sales = df_sales.merge(df_sales_stack, on='id')

# %%
del(df_sales_stack)

# %%
df_sales.head()
# Out:
#                        id              item    category    department  \
# 0  ACCESORIES_1_001_NYC_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
# 1  ACCESORIES_1_001_NYC_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
# 2  ACCESORIES_1_001_NYC_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
# 3  ACCESORIES_1_001_NYC_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
# 4  ACCESORIES_1_001_NYC_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
#
#                store store_code    region       date  sales_count
# 0  Greenwich_Village      NYC_1  New York 2011-02-06            0
# 1  Greenwich_Village      NYC_1  New York 2011-02-13            0
# 2  Greenwich_Village      NYC_1  New York 2011-02-20            0
# 3  Greenwich_Village      NYC_1  New York 2011-02-27            0
# 4  Greenwich_Village      NYC_1  New York 2011-03-06            0

# %%
len(df_sales.index.unique())
# Out:
# 8323770

# %%
len(df_sales.region.unique())
# Out:
# 3

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8323770 entries, 0 to 8323769
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           object
#  1   item         object
#  2   category     object
#  3   department   object
#  4   store        object
#  5   store_code   object
#  6   region       object
#  7   date         datetime64[ns]
#  8   sales_count  int64
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 893.1+ MB

# %%
order_of_columns = [
  'id',
  'date',
  'item',
  'category',
  'department',
  'store_code',
  'region',
  'store',
  'sales_count'
]
df_sales_merged = df_sales[order_of_columns]

# %%
df_sales_merged.head()
# Out:
#                        id       date              item    category  \
# 0  ACCESORIES_1_001_NYC_1 2011-02-06  ACCESORIES_1_001  ACCESORIES
# 1  ACCESORIES_1_001_NYC_1 2011-02-13  ACCESORIES_1_001  ACCESORIES
# 2  ACCESORIES_1_001_NYC_1 2011-02-20  ACCESORIES_1_001  ACCESORIES
# 3  ACCESORIES_1_001_NYC_1 2011-02-27  ACCESORIES_1_001  ACCESORIES
# 4  ACCESORIES_1_001_NYC_1 2011-03-06  ACCESORIES_1_001  ACCESORIES
#
#      department store_code    region              store  sales_count
# 0  ACCESORIES_1      NYC_1  New York  Greenwich_Village            0
# 1  ACCESORIES_1      NYC_1  New York  Greenwich_Village            0
# 2  ACCESORIES_1      NYC_1  New York  Greenwich_Village            0
# 3  ACCESORIES_1      NYC_1  New York  Greenwich_Village            0
# 4  ACCESORIES_1      NYC_1  New York  Greenwich_Village            0

# %%
df_sales_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8323770 entries, 0 to 8323769
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           object
#  1   date         datetime64[ns]
#  2   item         object
#  3   category     object
#  4   department   object
#  5   store_code   object
#  6   region       object
#  7   store        object
#  8   sales_count  int64
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 893.1+ MB

# %%
df_sales_merged.to_csv(os.path.join(DATA_PATH,"preproc_data/sales_cleaned.csv"))

# %%
full_df = df_sales_merged.merge(df_events, how='left', on = 'date')

# %%
df_prices
# Out:
#                       item       date store_code     category  sell_price
# 0         ACCESORIES_1_001 2013-07-21      BOS_1   ACCESORIES     12.7414
# 1         ACCESORIES_1_001 2013-07-21      NYC_1   ACCESORIES     12.7414
# 2         ACCESORIES_1_001 2013-07-21      NYC_4   ACCESORIES     12.7414
# 3         ACCESORIES_1_001 2013-07-21      PHI_1   ACCESORIES     12.7414
# 4         ACCESORIES_1_001 2013-07-28      BOS_1   ACCESORIES     10.9858
# ...                    ...        ...        ...          ...         ...
# 6721781  SUPERMARKET_3_827 2016-05-01      NYC_3  SUPERMARKET      1.2000
# 6721782  SUPERMARKET_3_827 2016-05-01      NYC_4  SUPERMARKET      1.2000
# 6721783  SUPERMARKET_3_827 2016-05-01      PHI_1  SUPERMARKET      1.2000
# 6721784  SUPERMARKET_3_827 2016-05-01      PHI_2  SUPERMARKET      1.2000
# 6721785  SUPERMARKET_3_827 2016-05-01      PHI_3  SUPERMARKET      1.2000
#
# [6721786 rows x 5 columns]

# %%
df_prices.drop_duplicates(inplace=True)

# %%
full_df = full_df.merge(df_prices[['date', 'sell_price', 'item', 'store_code']], how='left', on = ['item', 'store_code', 'date'])

# %%
full_df.shape
# Out:
# (8323770, 15)

# %%
df_sales_merged.shape
# Out:
# (8323770, 9)

# %%
full_df['revenue'] = full_df['sell_price'] * full_df['sales_count']

# %%
full_df.to_csv(os.path.join(DATA_PATH,"preproc_data/full_df.csv"))
